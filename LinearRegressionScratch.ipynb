# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt


df = pd.read_csv("food_truck_data (1).txt")
df.head(10)
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233
# 5      8.3829  11.8860
# 6      7.4764   4.3483
# 7      8.5781  12.0000
# 8      6.4862   6.5987
# 9      5.0546   3.8166

# %%
df.shape
# Out:
# (97, 2)

# %%
class LinearRegression:
    def __init__(self,lr=0.001,max_iter=100):
        self.lr=lr
        self.max_iter=max_iter
        self.theta=None
    def fit(self,X,y):
        m,n=X.shape
        self.theta=np.zeros((n,1))
        self.grad_desc(X,y)
    def predict(self,X):
        return np.dot(X,self.theta)
    def grad_desc(self,X,y):
        m,n=X.shape
        cost=[]
        for i in range(self.max_iter):
            y_pred=self.predict(X)
            error=y_pred-y
            grad=(2/m)*(np.dot(X.transpose(),error))
            self.theta-=self.lr*grad
            cost.append(self.compute_cost(X, y, self.theta))
        return self.theta
    def compute_cost(self,X,y,theta):
        m=len(y)
        J=np.sum((X.dot(theta)**2)-y/(2*m))
        return J

# %%
X=df[['Population']].values
y=df['Profit'].values.reshape(-1,1)
model= LinearRegression()
model.fit(X,y)
predicted_label=model.predict(X)
predicted_label
# Out:
# array([[ 4.90351921],
#        [ 4.43612758],
#        [ 6.83640509],
#        [ 5.62025592],
#        [ 4.70264674],
#        [ 6.7275022 ],
#        [ 6.00001162],
#        [ 6.88415543],
#        [ 5.20534955],
#        [ 4.05645213],
#        [ 4.58298999],
#        [11.36699007],
#        [ 4.60168887],
#        [ 6.74796663],
#        [ 4.52681311],
#        [ 4.31711285],
#        [ 5.10840431],
#        [ 4.11704291],
#        [ 5.15992653],
#        [ 5.67450674],
#        [ 4.96691883],
#        [16.26721892],
#        [ 4.40595257],
#        [ 5.076865  ],
#        [ 4.46598158],
#        [15.20387087],
#        [10.29481422],
#        [ 8.79328652],
#        [10.57409356],
#        [17.81850329],
#        [ 4.21519194],
#        [ 5.28817032],
#        [ 7.42192866],
#        [ 4.7283276 ],
#        [ 6.58962809],
#        [ 6.36676638],
#        [ 6.49717699],
#        [ 4.49920619],
#        [10.30123444],
#        [ 5.09877399],
#        [ 4.33918234],
# ...
